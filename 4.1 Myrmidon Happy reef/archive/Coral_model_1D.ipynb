# %% [markdown]
# ## Import all the necessary config files

# %%
from config import *
from utils import *

# %% [markdown]
# ## Run the coral model

# %%
run_coral_model(PSD_T0, MaxYear)
# Out:
#     Year  Branching_Area (%)  Foliose_Area (%)  Other_Area (%)  \
# 0      0            1.200000          2.200000       16.300000
# 1      1            1.302679          2.283267       16.945517
# 2      2            1.623721          2.387366       17.610166
# 3      3            2.310642          2.542025       18.461681
# 4      4            3.416365          2.769340       19.387826
# 5      5            5.073976          3.034549       20.387568
# 6      6            7.420465          3.336246       21.323961
# 7      7           10.512912          3.640830       22.323175
# 8      8           14.211865          3.943354       23.209027
# 9      9           18.381897          4.229936       24.261805
# 10    10           22.677440          4.487438       24.850437
# 11    11           26.844772          4.700872       25.581863
#
#     total_coral_cover (%)
# 0               19.700000
# 1               20.531463
# 2               21.621253
# 3               23.314349
# 4               25.573531
# 5               28.496093
# 6               32.080673
# 7               36.476917
# 8               41.364246
# 9               46.873638
# 10              52.015315
# 11              57.127508

# %% [markdown]
# ## Plot the change in total coral cover over the years

# %%
plt.plot(opts.yearly_total_coral_cover_df['total_coral_cover (%)'],'-*',label='Total')
plt.xlabel('Years', fontsize = '15')
plt.ylabel('Coral cover (%)', fontsize = '15')
# Out:
# Text(0, 0.5, 'Coral cover (%)')

# %% [markdown]
# ## The benthic cover over the years in percentage

# %%
opts.yearly_benthic_cover_df
# Out:
#     Year  total_benthic_cover (%)  available_substrate (%)  \
# 0      0                80.300000                72.800000
# 1      1                79.945368                72.584257
# 2      2                79.391130                72.171029
# 3      3                78.380985                71.278453
# 4      4                77.624069                70.619541
# 5      5                76.456972                69.534137
# 6      6                75.259742                68.404993
# 7      7                73.276282                66.478273
# 8      8                71.074919                64.324184
# 9      9                68.392871                61.681518
# 10    10                65.175486                58.496934
# 11    11                61.439675                54.788436
#
#     hard_substrate (%)  dead_coral (%)   CCA (%)  turfing_algae (%)  \
# 0             1.000000        1.000000  8.400000          62.400000
# 1             0.994839        1.133776  8.402920          62.077951
# 2             0.986539        1.240132  8.405371          61.560043
# 3             0.971155        1.317330  8.407442          60.600084
# 4             0.959665        1.382208  8.409185          59.883124
# 5             0.941831        1.423585  8.410660          58.770259
# 6             0.922730        1.502178  8.411909          57.578336
# 7             0.892342        1.499292  8.412979          55.682113
# 8             0.858610        1.481443  8.413898          53.577261
# 9             0.817240        1.459669  8.414694          50.995752
# 10            0.767946        1.398593  8.415390          47.919845
# 11            0.710719        1.316845  8.416006          44.348874
#
#     macro_algae (%)  rubble (%)  sediment (%)  total_cc   unavailable_sub  \
# 0          5.500000    1.000000      1.000000  19.700000         7.500000
# 1          5.501912    0.833623      1.000348  20.054632         7.333333
# 2          5.503517    0.694888      1.000639  20.608870         7.196945
# 3          5.504873    0.579216      1.000886  21.619015         7.083230
# 4          5.506014    0.482780      1.001093  22.375931         6.988439
# 5          5.506980    0.402388      1.001269  23.543028         6.909424
# 6          5.507798    0.335373      1.001418  24.740258         6.843572
# 7          5.508498    0.279513      1.001545  26.723718         6.788693
# 8          5.509100    0.232953      1.001655  28.925081         6.742971
# 9          5.509621    0.194146      1.001749  31.607129         6.704882
# 10         5.510077    0.161801      1.001832  34.824514         6.673159
# 11         5.510480    0.134844      1.001905  38.560325         6.646744
#
#            tot
# 0   100.000000
# 1    99.972222
# 2    99.976844
# 3    99.980698
# 4    99.983911
# 5    99.986589
# 6    99.988823
# 7    99.990684
# 8    99.992236
# 9    99.993529
# 10   99.994607
# 11   99.995506

# %% [markdown]
# ## Plot the benthic cover over the years for turfing algae, dead coral, rubble, macro algae and total coral cover in percentage

# %%
plt.plot(opts.yearly_benthic_cover_df['turfing_algae (%)'],label='TF')
plt.plot(opts.yearly_benthic_cover_df['dead_coral (%)'],label='DC')
plt.plot(opts.yearly_benthic_cover_df['rubble (%)'],label='R')
plt.plot(opts.yearly_benthic_cover_df['macro_algae (%)'],label='MA')
plt.plot(opts.yearly_benthic_cover_df['total_cc '],label='TCC')
plt.legend()

# %% [markdown]
# ## Export the data frames to excel

# %%
# This function exports the data frames to excel 

export_to_excel(opts.yearly_population_df_list,'yearly_population')
export_to_excel(opts.yearly_surface_area_df_list,'yearly_surface_area')
export_to_excel(opts.yearly_total_coral_cover_df,'yearly_total_coral_cover')
export_to_excel(opts.yearly_benthic_cover_df,'yearly_benthic_cover')

# %% [markdown]
# ## Plots

# %%
plot_coral_type_population_change('Foliose', 0,1,2,3)
# plot_coral_type_population_change('Foliose',True, 0,1,2,3,11)

# %%
plot_coral_type_areal_change('Other',0,4,7,11)

# %%
plot_coral_type_areal_change('Branching',0,4,7,11)

# %%
plot_coral_type_areal_change('Foliose',0,4,7,11)

# %%
plot_coral_type_areal_change('Other',0,4,7,11)

# %%
plot_coral_type_areal_change('Other',0,4,7,11)

# %%
plot_surface_area_distribution(4)

# %%
# This plot the Area of the coral type chosen for different input years

plot_coral_type_areal_change('Foliose',0,2,4)

# %%
# This function plot the percentage population distribution of the bins. For example: 100*branching_population_bin_2/total_branching_population 

plot_population_distribution_in_percentage(4)

# %% [markdown]
# ## Rugosity

# %%
# This function calculates the Rugosity and returns them in a list

rugosity_list = get_rugosity_list()
export_to_excel(rugosity_list,'Rugosity')

# %%
# This function plots the rugosity values over the years

plot_rugosity_year()

# %%
plot_rugosity_total_coral_cover()

# %% [markdown]
# ## Run simulation for n number of times and plot the total coral cover

# %%
# run the model for n number of iteration
number_of_iteration = 100
iteration_df = run_multiple_model_iterations(number_of_iteration)
plot_growth_rate_iterations(iteration_df)

# %%
iteration_df
# Out:
# 5      23.984357     23.780382      24.019306  23.939181
# 6      25.515244     25.363205      26.516432  25.658409
# 7      27.457155     27.078104      29.136424  27.808337
# 8      29.734198     29.457221      31.911933  30.522924
# 9      32.986790     32.328069      35.923559  33.703888
# 10     36.591153     35.790394      40.110438  37.310228
# 11     40.648876     39.222888      44.172238  41.268474
#
# [12 rows x 102 columns]

# %% [markdown]
# ## The effect of cyclone on the whole colony mortality

# %%
# WCM_rates are the background whole colony mortality rates under no external stressor
# WCM_rates_during_cyclone is the calculated whole colony mortality rates during cyclone

cyclone = True
cyclone_severity_level = 1
distance_to_cyclone = 106

WCM_rates_during_cyclone = get_WCM_rates_after_cyclones(WCM_rates, cyclone_severity_level, distance_to_cyclone)
WCM_rates_during_cyclone
# Out:
#     Branching  Foliose  Other
# 0       0.200     0.20   0.20
# 1       0.148     0.04   0.04
# 2       0.148     0.04   0.04
# 3       0.076     0.04   0.04
# 4       0.076     0.02   0.02
# 5       0.076     0.02   0.02
# 6       0.076     0.02   0.02
# 7       0.076     0.02   0.02
# 8       0.076     0.02   0.02
# 9       0.076     0.02   0.02
# 10      0.076     0.02   0.02
# 11      0.076     0.02   0.02
# 12      0.076     0.02   0.02
# 13      0.076     0.02   0.02
# 14      0.076     0.02   0.02
# 15      0.076     0.02   0.02
# 16      0.076     0.02   0.02
# 17      0.076     0.02   0.02
# 18      0.076     0.02   0.02
# 19      0.076     0.02   0.02

# %% [markdown]
# ## The effect of bleaching on the partial colony mortality

# %%
# PCM_rates are the background partial colony mortality rates under no external stressor
# PCM_rates_during_bleaching is the calculated partial colony mortality rates during bleaching event

branching_bleaching_rate = 34
foliose_bleaching_rate = 17
other_bleaching_rate = 17

dhw = 8

PCM_rates_during_bleaching = get_PCM_rates_after_dhw(PCM_rates, dhw, branching_bleaching_rate, foliose_bleaching_rate, other_bleaching_rate)
PCM_rates_during_bleaching
# Out:
#     Branching   Foliose     Other
# 0    0.030115  0.058282  0.058282
# 1    0.034776  0.066996  0.066996
# 2    0.040335  0.077298  0.077298
# 3    0.046991  0.089494  0.089494
# 4    0.054986  0.103949  0.103949
# 5    0.064618  0.121082  0.121082
# 6    0.076247  0.141367  0.141367
# 7    0.090311  0.165327  0.165327
# 8    0.107326  0.193507  0.193507
# 9    0.127892  0.226442  0.226442
# 10   0.152686  0.264591  0.264591
# 11   0.182432  0.308253  0.308253
# 12   0.217849  0.357463  0.357463
# 13   0.259560  0.411874  0.411874
# 14   0.307959  0.470662  0.470662
# 15   0.363040  0.532487  0.532487
# 16   0.424219  0.595552  0.595552
# 17   0.490204  0.657765  0.657765
# 18   0.558981  0.717004  0.717004
# 19   0.627967  0.771394  0.771394
