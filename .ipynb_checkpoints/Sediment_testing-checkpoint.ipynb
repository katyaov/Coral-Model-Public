# %%
#Rio's sediment testing script

# %%
#print
from user_inputs import sediment_years, year_start

def print_sediment_data():
    print("Sediment Data:")
    print("Year\tMonth\tSuspended Sediment (mg/L)\tDeposited Sediment (mg/cm²)")
    for year_offset, data in sediment_years.items():
        year = year_start + year_offset
        month, suspended_sediment, deposited_sediment = data
        print(f"{year}\t{month}\t{suspended_sediment}\t\t\t{deposited_sediment}")

# Call the function to print the sediment data
print_sediment_data()
# Out:
# Sediment Data:
# Year	Month	Suspended Sediment (mg/L)	Deposited Sediment (mg/cm²)
# 2005	12	5			10
# 2006	12	20			30
# 2007	12	5			10
# 2008	12	5			10
# 2009	12	5			10
# 2010	12	5			10
# 2011	12	5			10
# 2012	12	5			10
# 2013	12	5			10
# 2014	12	5			10
# 2015	12	5			10
# 2016	12	5			10
# 2017	12	5			10
# 2018	12	5			10
# 2019	12	5			10
# 2020	12	5			10
# 2021	12	5			10
# 2022	12	5			10
# 2023	12	5			10
# 2024	12	5			10

# %%
# Print the additional sediment data (optional, for debugging purposes)
print("Additional Sediment Data Above Baseline:")
for year_offset, data in additional_sediment_data.items():
    print(f"Year Offset: {year_offset}, Month: {data['Month']}, "
          f"Additional Suspended: {data['Additional_Suspended']} mg/L, "
          f"Additional Deposited: {data['Additional_Deposited']} mg/cm²")
# Out:
# Additional Sediment Data Above Baseline:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 # Print the additional sediment data (optional, for debugging purposes)
#       2 print("Additional Sediment Data Above Baseline:")
# ----> 3 for year_offset, data in additional_sediment_data.items():
#       4     print(f"Year Offset: {year_offset}, Month: {data['Month']}, "
#       5           f"Additional Suspended: {data['Additional_Suspended']} mg/L, "
#       6           f"Additional Deposited: {data['Additional_Deposited']} mg/cm²")
#
# NameError: name 'additional_sediment_data' is not defined
