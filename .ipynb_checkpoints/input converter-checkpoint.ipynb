# %%
from convert_coral_inputs3 import convert
out_xlsx, out_py = convert(
    old_py_path="4.1 Myrmidon Happy reef/user_inputs_old_4-1.py",   # <-- change to your uploaded file
    template_excel_path="coral_data_and_custom_parameters.xlsx",
    out_excel_path="4.1 Myrmidon Happy reef/coral_data_and_custom_parameters.xlsx",
    out_user_input_path="4.1 Myrmidon Happy reef/user_inputs.py",
    template_user_input_path="user_inputs.py"
)
out_xlsx, out_py
# Out:
# Excel file saved to: 4.1 Myrmidon Happy reef/coral_data_and_custom_parameters.xlsx
# Python file saved to: 4.1 Myrmidon Happy reef/user_inputs.py
# ('4.1 Myrmidon Happy reef/coral_data_and_custom_parameters.xlsx',
#  '4.1 Myrmidon Happy reef/user_inputs.py')

# %%
from convert_coral_inputs3 import convert
out_xlsx, out_py = convert(
    old_py_path="5. Knife/user_inputs_old_5.py",   # <-- change to your uploaded file
    template_excel_path="coral_data_and_custom_parameters.xlsx",
    out_excel_path="5. Knife/coral_data_and_custom_parameters.xlsx",
    out_user_input_path="5. Knife/user_inputs.py"
)
out_xlsx, out_py
# Out:
# Excel file saved to: 5. Knife/coral_data_and_custom_parameters.xlsx
# Python file saved to: 5. Knife/user_inputs.py
# ('5. Knife/coral_data_and_custom_parameters.xlsx', '5. Knife/user_inputs.py')

# %%
from convert_coral_inputs3 import convert
out_xlsx, out_py = convert(
    old_py_path="6.1 Myrmidon disturbance/user_inputs_old_6-1.py",   # <-- change to your uploaded file
    template_excel_path="coral_data_and_custom_parameters.xlsx",
    out_excel_path="6.1 Myrmidon disturbance/coral_data_and_custom_parameters.xlsx",
    out_user_input_path="6.1 Myrmidon disturbance/user_inputs.py"
)
out_xlsx, out_py
# Out:
# Excel file saved to: 6.1 Myrmidon disturbance/coral_data_and_custom_parameters.xlsx
# Python file saved to: 6.1 Myrmidon disturbance/user_inputs.py
# ('6.1 Myrmidon disturbance/coral_data_and_custom_parameters.xlsx',
#  '6.1 Myrmidon disturbance/user_inputs.py')

# %%
from convert_coral_inputs3 import convert
out_xlsx, out_py = convert(
    old_py_path="6.2 Geoffrey Bay/user_inputs_old_6-2.py",   # <-- change to your uploaded file
    template_excel_path="coral_data_and_custom_parameters.xlsx",
    out_excel_path="6.2 Geoffrey Bay/coral_data_and_custom_parameters.xlsx",
    out_user_input_path="6.2 Geoffrey Bay/user_inputs.py"
)
out_xlsx, out_py
# Out:
# Excel file saved to: 6.2 Geoffrey Bay/coral_data_and_custom_parameters.xlsx
# Python file saved to: 6.2 Geoffrey Bay/user_inputs.py
# ('6.2 Geoffrey Bay/coral_data_and_custom_parameters.xlsx',
#  '6.2 Geoffrey Bay/user_inputs.py')

# %%
from convert_coral_inputs3 import convert
out_xlsx, out_py = convert(
    old_py_path="6.3 Moorea disturbances/user_inputs_old_6-3.py",   # <-- change to your uploaded file
    template_excel_path="coral_data_and_custom_parameters.xlsx",
    out_excel_path="6.3 Moorea disturbances/coral_data_and_custom_parameters.xlsx",
    out_user_input_path="6.3 Moorea disturbances/user_inputs.py"
)
out_xlsx, out_py
# Out:
# Excel file saved to: 6.3 Moorea disturbances/coral_data_and_custom_parameters.xlsx
# Python file saved to: 6.3 Moorea disturbances/user_inputs.py
# ('6.3 Moorea disturbances/coral_data_and_custom_parameters.xlsx',
#  '6.3 Moorea disturbances/user_inputs.py')

# %%
from convert_coral_inputs3 import convert
out_xlsx, out_py = convert(
    old_py_path="6.4 Bonaire with disturbances/user_inputs_old_6-4.py",   # <-- change to your uploaded file
    template_excel_path="coral_data_and_custom_parameters.xlsx",
    out_excel_path="6.4 Bonaire with disturbances/coral_data_and_custom_parameters.xlsx",
    out_user_input_path="6.4 Bonaire with disturbances/user_inputs.py"
)
out_xlsx, out_py
# Out:
# Excel file saved to: 6.4 Bonaire with disturbances/coral_data_and_custom_parameters.xlsx
# Python file saved to: 6.4 Bonaire with disturbances/user_inputs.py
# ('6.4 Bonaire with disturbances/coral_data_and_custom_parameters.xlsx',
#  '6.4 Bonaire with disturbances/user_inputs.py')

# %%
from convert_coral_inputs3 import convert
out_xlsx, out_py = convert(
    old_py_path="7 Future comparisons/Bonaire/user_inputs_old_7-1.py",   # <-- change to your uploaded file
    template_excel_path="coral_data_and_custom_parameters.xlsx",
    out_excel_path="7 Future comparisons/Bonaire/coral_data_and_custom_parameters.xlsx",
    out_user_input_path="7 Future comparisons/Bonaire/user_inputs.py"
)
out_xlsx, out_py
# Out:
# Excel file saved to: 7 Future comparisons/Bonaire/coral_data_and_custom_parameters.xlsx
# Python file saved to: 7 Future comparisons/Bonaire/user_inputs.py
# ('7 Future comparisons/Bonaire/coral_data_and_custom_parameters.xlsx',
#  '7 Future comparisons/Bonaire/user_inputs.py')

# %%
from convert_coral_inputs3 import convert
out_xlsx, out_py = convert(
    old_py_path="7 Future comparisons/Myrmidon/user_inputs_old_7-2.py",   # <-- change to your uploaded file
    template_excel_path="coral_data_and_custom_parameters.xlsx",
    out_excel_path="7 Future comparisons/Myrmidon/coral_data_and_custom_parameters.xlsx",
    out_user_input_path="7 Future comparisons/Myrmidon/user_inputs.py"
)
out_xlsx, out_py
# Out:
# Excel file saved to: 7 Future comparisons/Myrmidon/coral_data_and_custom_parameters.xlsx
# Python file saved to: 7 Future comparisons/Myrmidon/user_inputs.py
# ('7 Future comparisons/Myrmidon/coral_data_and_custom_parameters.xlsx',
#  '7 Future comparisons/Myrmidon/user_inputs.py')
