# %% [markdown]
# ## Import all the necessary config files

# %%
from config import *
from utils import *
import matplotlib.ticker as mticker
import matplotlib.pyplot as plt

# %% [markdown]
# ## Run the coral model

# %%
# This runs the model once for the number of years selected in the user input files
run_coral_model(PSD_T0, MaxYear)
# Out:
#     Year  Branching_Area (%)  Foliose_Area (%)  Other_Area (%)  \
# 0      0            2.600000          7.300000        8.000000
# 1      1            2.593139          7.678040        8.191445
# 2      2            1.082921          4.424581        5.827164
# 3      3            1.185569          4.985719        6.155875
# 4      4            1.309689          5.695797        6.547773
# 5      5            1.440720          6.540884        6.974049
# 6      6            1.580393          7.524562        7.428039
# 7      7            1.721079          8.633241        7.936589
# 8      8            1.071283          6.448885        6.267929
# 9      9            1.008392          6.779007        6.179532
# 10    10            1.097103          7.973323        6.697120
# 11    11            0.874747          7.571651        6.205775
# 12    12            0.958598          8.841571        6.672222
# 13    13            0.936342          9.526124        6.802068
# 14    14            1.033348         11.116143        7.324780
# 15    15            0.627396          8.360014        6.157158
# 16    16            0.501005          7.367015        5.704484
# 17    17            0.594929          9.118227        6.373437
# 18    18            0.686389         10.944838        6.981640
# 19    19            0.769396         12.791063        7.532459
#
#     total_coral_cover (%)
# 0               17.900000
# 1               18.462624
# 2               11.334665
# 3               12.327163
# 4               13.553259
# 5               14.955653
# 6               16.532995
# 7               18.290909
# 8               13.788097
# 9               13.966932
# 10              15.767546
# 11              14.652172
# 12              16.472391
# 13              17.264534
# 14              19.474271
# 15              15.144568
# 16              13.572505
# 17              16.086594
# 18              18.612866
# 19              21.092918

# %% [markdown]
# ## Plot the change in total coral cover over the years

# %%
# Build actual years based on row count
n = len(opts.yearly_total_coral_cover_df)
actual_years = range(year_start, year_start + n)

# Plot with actual years as x-values
plt.plot(actual_years,
         opts.yearly_total_coral_cover_df['total_coral_cover (%)'],
         '-*',
         label='Total')

plt.xlabel('Years', fontsize=15)
plt.ylabel('Coral cover (%)', fontsize=15)
plt.legend()

# Make x-axis labels integers only
plt.gca().xaxis.set_major_formatter(mticker.FormatStrFormatter('%d'))

plt.show()

# %% [markdown]
# ## The benthic cover over the years in percentage

# %%
opts.yearly_benthic_cover_df
# Out:
#     Year  total_benthic_cover (%)  available_substrate (%)  \
# 0      0                89.100000                43.300000
# 1      1                81.537376                43.292932
# 2      2                88.665335                42.863998
# 3      3                87.672837                42.963074
# 4      4                86.446741                42.649952
# 5      5                85.044347                42.010355
# 6      6                83.467005                41.069782
# 7      7                81.709091                39.843013
# 8      8                86.211903                42.944656
# 9      9                86.033068                43.136674
# 10    10                84.232454                41.723582
# 11    11                85.347828                42.672592
# 12    12                83.527609                41.150672
# 13    13                82.735466                40.587715
# 14    14                80.525729                38.587838
# 15    15                84.855432                41.434592
# 16    16                86.427495                42.143610
# 17    17                83.913406                39.954381
# 18    18                81.387134                37.698345
# 19    19                78.907082                35.442997
#
#     hard_substrate (%)  dead_coral (%)   CCA (%)  turfing_algae (%)  \
# 0             2.400000        4.000000  0.800000          36.100000
# 1             2.183378        4.157480  0.737676          32.841642
# 2             2.189158        6.527467  0.739629          33.521226
# 3             2.142498        7.368618  0.741283          32.806749
# 4             2.084362        7.987118  0.742686          31.916545
# 5             2.017981        8.415886  0.743879          30.900099
# 6             1.943625        8.675841  0.744895          29.761520
# 7             1.861177        8.783413  0.745763          28.499043
# 8             1.863280       10.566262  0.746605          29.817040
# 9             1.850504       10.938384  0.747326          29.642084
# 10            1.773432       10.828991  0.747940          28.407515
# 11            1.774760       11.454605  0.748500          28.726686
# 12            1.698847       11.231161  0.748978          27.497945
# 13            1.665531       11.236215  0.749386          26.958689
# 14            1.573934       10.806108  0.749735          25.476064
# 15            1.574724       12.333131  0.750112          26.797429
# 16            1.575996       12.918602  0.750718          26.932330
# 17            1.481379       12.434050  0.751238          25.315427
# 18            1.386812       11.882964  0.751686          23.699363
# 19            1.294443       11.293814  0.752072          22.120844
#
#     macro_algae (%)  rubble (%)  sediment (%)  total_cc   unavailable_sub  \
# 0         36.800000    4.000000      5.000000  17.900000        45.800000
# 1         33.933079    3.073648      4.610473  18.462624        45.133333
# 2         34.022917    7.042259      4.622679  11.334665        45.567215
# 3         34.099000    5.881672      4.633016  12.327163        44.514145
# 4         34.163567    4.910674      4.641789  13.553259        43.633410
# 5         34.218452    4.098803      4.649246  14.955653        42.897585
# 6         34.265193    3.420335      4.655597  16.532995        42.283367
# 7         34.305082    2.853597      4.661017  18.290909        41.771068
# 8         35.629639    2.922793      4.666284  13.788097        43.169931
# 9         35.693513    2.490471      4.670786  13.966932        42.813459
# 10        35.722852    2.077098      4.674626  15.767546        42.439692
# 11        36.047503    1.917647      4.678127  14.652172        42.611363
# 12        36.070506    1.599059      4.681112  16.472391        42.323669
# 13        36.090151    1.351832      4.683662  17.264534        42.102714
# 14        36.106989    1.127052      4.685847  19.474271        41.900339
# 15        37.433691    1.278145      4.688199  15.144568        43.378256
# 16        37.463922    2.093942      4.691986  13.572505        44.214143
# 17        37.489909    1.746162      4.695240  16.086594        43.900860
# 18        37.512265    1.456003      4.698040  18.612866        43.640284
# 19        37.531502    1.213958      4.700449  21.092918        43.423641
#
#            tot
# 0   107.000000
# 1   106.888889
# 2    99.765878
# 3    99.804382
# 4    99.836620
# 5    99.863592
# 6    99.886144
# 7    99.904991
# 8    99.902684
# 9    99.917064
# 10   99.930820
# 11   99.936126
# 12   99.946732
# 13   99.954963
# 14   99.962449
# 15   99.957417
# 16   99.930258
# 17   99.941835
# 18   99.951496
# 19   99.959555

# %% [markdown]
# ## Plot the benthic cover over the years for turfing algae, dead coral, rubble, macro algae and total coral cover in percentage

# %%
# Make a clean working copy and normalise column names
df = opts.yearly_benthic_cover_df.copy()
df.columns = df.columns.str.strip()

# Replace index with actual years
n = len(df)
actual_years = range(year_start, year_start + n)  # real years
df.index = pd.Index(actual_years, name="Year")

# Create a single plot
fig, ax = plt.subplots(figsize=(8, 5))

ax.plot(df['turfing_algae (%)'], label='TF')
ax.plot(df['dead_coral (%)'], label='DC')
ax.plot(df['rubble (%)'], label='R')
ax.plot(df['macro_algae (%)'], label='MA')
ax.plot(df['total_cc'], label='TCC')

ax.set_xlabel('Year')
ax.set_ylabel('Cover (%)')
ax.set_title('Benthic Cover')
ax.legend()

# Force integer year labels
ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%d'))

plt.show()

# %% [markdown]
# ## Export the data frames to excel

# %%
# This function exports data frames to Excel 

export_to_excel(opts.yearly_population_df_list,'yearly_population')
export_to_excel(opts.yearly_surface_area_df_list,'yearly_surface_area')
export_to_excel(opts.yearly_total_coral_cover_df,'yearly_total_coral_cover')
export_to_excel(opts.yearly_benthic_cover_df,'yearly_benthic_cover')

# %% [markdown]
# ## Plots

# %%
#Coral Cover Population

#Years you want to be plotted:
Years = 2007, 2008, 2009

#Convert them to model years (indices) for the model)
model_years = tuple(year - year_start for year in Years)

#Plot coral population change by type
plot_coral_type_population_change('Foliose', False, *model_years)

# %%
# This plots the Area of the coral type chosen for different input years
# Other

#Years you want to be plotted:
Years = 2007, 2008, 2009

#Convert them to model years (indices) for the model)
model_years = tuple(year - year_start for year in Years)

#Plot coral area change by type
plot_coral_type_areal_change('Other', False, *model_years)

# %%
# This plots the Area of the coral type chosen for different input years
# Branching

#Years you want to be plotted:
Years = 2007, 2008, 2009

#Convert them to model years (indices) for the model)
model_years = tuple(year - year_start for year in Years)

plot_coral_type_areal_change('Branching', False, *model_years)

# %%
# This plots the Area of the coral type chosen for different input years
# Foliose

#Years you want to be plotted:
Years = 2007, 2008, 2009

#Convert them to model years (indices) for the model)
model_years = tuple(year - year_start for year in Years)

plot_coral_type_areal_change('Foliose',False, *model_years)

# %%
# Plot surface area distribution of different coral types in a given year.

Year = 2006

#Convert them to model years (indices) for the model)
model_year = Year - year_start

plot_surface_area_distribution(model_year)

# %%
# This function plots the percentage population distribution of the bins in a given year. 
# plot_population_distribution_in_percentage(year)
# For example: 100*branching_population_bin_2/total_branching_population 

Year = 2009

#Convert them to model years (indices) for the model)
model_year = Year - year_start

plot_population_distribution_in_percentage(model_year)

# %% [markdown]
# ## Rugosity

# %%
# This function calculates the Rugosity and returns them in a list

rugosity_list = get_rugosity_list()
export_to_excel(rugosity_list,'Rugosity')

# %%
# This function plots the rugosity values over the years

plot_rugosity_year()

# %%
plot_rugosity_total_coral_cover()

# %% [markdown]
# ## Run simulation for n number of times and plot the total coral cover

# %%
# run the model for n number of